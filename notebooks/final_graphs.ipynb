# %% [markdown]
# # Final Report Graphs: All Methods Comparison
#
# Member C — Joseph Nguyen
#
# This notebook produces the final publication-quality figures for the CS 175 report.
# Combines planner results and RL results into unified comparison charts.
#
# ## Sections to build:
# 1. Load all results (planner + RL)
# 2. Master success rate comparison (BFS, Greedy, PPO, DQN)
# 3. Steps to solution (solved episodes only)
# 4. Runtime comparison (planners in ms, RL inference in ms)
# 5. Scalability: performance vs level difficulty
# 6. Summary table (for report)
# 7. Export all figures to report/ as .png

# %%
# TODO: import pandas, matplotlib, seaborn
# TODO: load results/planner_results.csv
# TODO: load results/ppo_results.csv
# TODO: load results/dqn_results.csv
# TODO: concat into one master DataFrame

# %%
# TODO: master success rate bar chart
# four bars: BFS, Greedy, PPO, DQN
# with error bars (std across levels)

# %%
# TODO: steps boxplot — all four methods side by side
# only include solved episodes

# %%
# TODO: runtime comparison
# planners: measured in planner_runner.py
# RL: inference time per episode from evaluate.py

# %%
# TODO: summary table with metrics.compare_methods()
# print as formatted table, also export as CSV

# %%
# TODO: save all figures
# plt.savefig('report/fig_success_rate.png', dpi=150, bbox_inches='tight')
# etc.
