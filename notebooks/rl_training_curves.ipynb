# %% [markdown]
# # RL Training Curves: PPO and DQN
#
# Member B — Shizuka Takao / Member C — Joseph Nguyen
#
# This notebook visualizes how PPO and DQN agents learn over time.
# Loads training logs from `results/training_log.csv` written by `callbacks.py`.
#
# ## Sections to build:
# 1. Load training log CSV
# 2. Reward over timesteps (smoothed line chart)
# 3. Success rate over timesteps
# 4. PPO vs DQN learning speed comparison
# 5. Sample efficiency analysis (steps to reach X% success)

# %%
# TODO: import pandas, matplotlib
# TODO: load results/training_log.csv
# TODO: preview shape and columns

# %%
# TODO: smooth reward curve with rolling mean (window=10)
# plot mean_reward vs timestep for PPO and DQN on same axes

# %%
# TODO: success rate over time
# plot success_rate vs timestep for PPO and DQN

# %%
# TODO: find timestep where each method first exceeds 50% success
# report as sample efficiency metric
